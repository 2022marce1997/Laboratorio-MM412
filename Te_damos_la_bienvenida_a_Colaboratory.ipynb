# %% [markdown]
# <a href="https://colab.research.google.com/github/2022marce1997/Laboratorio-MM412/blob/main/Te_damos_la_bienvenida_a_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Análisis Numérico
#
# Laboratorio 1 **texto en negrita**
#
# ¿Qué son las Bibliotecas en Python?
#
# Las bibliotecas en Python son conjuntos de módulos, que son archivos que contienen funciones, clases y variables, diseñados para realizar tareas específicas. Estas bibliotecas proporcionan funcionalidades predefinidas para resolver problemas comunes de manera eficiente, evitando que tengas que escribir código desde cero.
#
# Módulo: Es un archivo con código en Python, que puede contener funciones, variables y clases.
#
# Biblioteca: Una biblioteca es un conjunto de módulos que agrupan funcionalidades relacionadas. Por ejemplo, una biblioteca puede contener varios módulos para operaciones matemáticas, gráficos o manejo de fechas.
#
# Bibliotecas Estándar
#
# Son las que vienen preinstaladas con Python. Ejemplos Comunes:
#
# math: Funciones matemáticas básicas.
#
# **MATH:**

# %%
import math #instrucción para llamar la biblioteca
x=16 #declaración de variable
# calcular la raíz cudrada de x
resultado=math.sqrt(x)  #función raíz cuadrada
print("La raíz cuadrada de 16 es:",resultado)
# Out:
# La raíz cuadrada de 16 es: 4.0

# %% [markdown]
# numpy: Para trabajar con arreglos y álgebra lineal.
#
# **NUMPY**:

# %%
import numpy as np
arr = np.array([1, 2, 3, 4])
#Realizar una operación sobre el array
squared = np.sqrt(arr)  #Raíz cuadrada de cada elemento
print("Las raíces cuadradas de los elementos son:", squared)
# Out:
# Las raíces cuadradas de los elementos son: [1.         1.41421356 1.73205081 2.        ]

# %% [markdown]
# matplotlib: Para crear gráficos y visualizaciones.
# **matplotlib:**

# %%
import matplotlib.pyplot as plt
x=np.linspace(-10, 10, 100) #generar 100 puntos de -10 a 10
y=x**2 #función cuadrática
plt.plot(x, y)
plt.title("Gráfico de f(x)=x^2")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.grid(True)
plt.show()

# %% [markdown]
# scipy
#
# Permite realizar optimización y encontrar raíces de funciones.
#
# **scipy:**

# %%
import scipy.optimize as opt

def f(x):
  return x**2-4  #Raíz de esta función es 2

 #Encontrar la raíz
